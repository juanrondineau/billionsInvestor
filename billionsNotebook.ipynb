# %% [markdown]
# Paquetes a instalar

# %%
! pip install yfinance
! pip install PySpark
! pip install finvizfinance
# Out:
# Requirement already satisfied: yfinance in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: peewee>=3.16.2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: pytz>=2022.5 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (2023.4)
# Requirement already satisfied: requests>=2.31 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: lxml>=4.9.1 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: html5lib>=1.1 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: appdirs>=1.4.4 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from yfinance) (1.26.3)
# Requirement already satisfied: soupsieve>1.2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.2.0)
# Collecting PySpark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 783.0 kB/s eta 0:00:00m eta 0:00:010:00:09
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 KB 589.0 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Using legacy 'setup.py install' for PySpark, since package 'wheel' is not installed.
# Installing collected packages: py4j, PySpark
#   Running setup.py install for PySpark ... done
# Successfully installed PySpark-3.5.1 py4j-0.10.9.7
# Collecting finvizfinance
#   Downloading finvizfinance-0.14.7-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 KB 355.1 kB/s eta 0:00:001m159.6 kB/s eta 0:00:01
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: lxml in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from finvizfinance) (5.2.1)
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 KB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: requests in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from finvizfinance) (2.31.0)
# Requirement already satisfied: pandas in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from finvizfinance) (2.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from bs4->finvizfinance) (4.12.3)
# Requirement already satisfied: pytz in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from datetime->finvizfinance) (2023.4)
# Collecting zope.interface
#   Downloading zope.interface-6.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.3/247.3 KB 800.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from pandas->finvizfinance) (1.26.3)
# Requirement already satisfied: tzdata>=2022.7 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from pandas->finvizfinance) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from pandas->finvizfinance) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests->finvizfinance) (2.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests->finvizfinance) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests->finvizfinance) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from requests->finvizfinance) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->finvizfinance) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from beautifulsoup4->bs4->finvizfinance) (2.5)
# Requirement already satisfied: setuptools in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from zope.interface->datetime->finvizfinance) (59.6.0)
# Installing collected packages: zope.interface, datetime, bs4, finvizfinance
# Successfully installed bs4-0.0.2 datetime-5.5 finvizfinance-0.14.7 zope.interface-6.2

# %% [markdown]
# Imports

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import math
from finvizfinance.quote import finvizfinance

# %% [markdown]
# Ejemplos llamadas apis x ticker

# %%
yfinInfo = yf.Ticker('SONY').info
tickerFinancialDf = yf.Ticker('RIO').financials
print(tickerFinancialDf)

stock = finvizfinance('STLD')
stock_fundament = stock.ticker_fundament()
#print(stock_fundament)
#print(stock_fundament['EPS past 5Y'])

# %% [markdown]
# Inicializo Objetos

# %%
tickers = ['AMBA','PATH','PFE', 'SONY', 'TM', 'AEP', 'EPD', 'TSLA', 'GOOGL', 'IPG']
year = '2023'
finalDF = pd.DataFrame()

# %% [markdown]
# Armado de Pandas DataFrame con info básica de los tickers

# %%
tickersData = []

for ticker in tickers:

  yFinanceInfo = yf.Ticker(ticker).info
  finVizFundamentsInfo = finvizfinance(ticker).ticker_fundament()

  tickerData = [
      ticker,
      yFinanceInfo['shortName'],
      yFinanceInfo['sectorDisp'],
      yFinanceInfo['industryDisp'],
      yFinanceInfo['country'],
      round(yFinanceInfo['marketCap']/1000000000,2),
      round(yFinanceInfo['priceToBook'],2),
      round(yFinanceInfo['dividendYield']*100,2) if 'dividendYield' in yFinanceInfo.keys() else 0,
      round(yFinanceInfo['payoutRatio']*100,2) if 'payoutRatio' in yFinanceInfo.keys() else 0,
      yFinanceInfo['trailingEps'],
      finVizFundamentsInfo['EPS past 5Y'][:len(finVizFundamentsInfo['EPS past 5Y'])-1] if finVizFundamentsInfo['EPS past 5Y'] != '-' else 0,
      round(yFinanceInfo['returnOnEquity']*100,2),
      round(yFinanceInfo['currentRatio'],2),
      finVizFundamentsInfo['LT Debt/Eq'],
      round(yFinanceInfo['debtToEquity']/100,2),
      round(yFinanceInfo['currentPrice'],2)
  ]

  tickersData.append(tickerData)

columnsNames = ['Ticker','Company','Sector','Industry','Country','MarketCap(BN)','P/B', 'Dividend Yield(%)', 'Payout Ratio (%)', 'EPS(ttm)', 'EPS growth past 5 years(%)','ROE(%)', 'Current Ratio','LT Debt/Equity','Total Debt/Equity', 'Price',]

df = pd.DataFrame(tickersData, index = tickers, columns=columnsNames )

df["P/E"] = round(df["Price"] / df["EPS(ttm)"],2)
df["E/P (%)"] = round(df["EPS(ttm)"] / df["Price"] * 100,2)
df["PriceToAssets"] = round((22.5*df["EPS(ttm)"]*df["P/B"]).apply(np.sqrt),2)

# Change column B and C's values to integers
df = df.astype({'EPS growth past 5 years(%)': float, 'LT Debt/Equity':float})

#df.info()
print(df)
# Out:
#       Ticker                          Company                  Sector  \
# AMBA    AMBA                  Ambarella, Inc.              Technology
# PATH    PATH                     UiPath, Inc.              Technology
# PFE      PFE                     Pfizer, Inc.              Healthcare
# SONY    SONY           Sony Group Corporation              Technology
# TM        TM         Toyota Motor Corporation       Consumer Cyclical
# AEP      AEP  American Electric Power Company               Utilities
# EPD      EPD  Enterprise Products Partners L.                  Energy
# TSLA    TSLA                      Tesla, Inc.       Consumer Cyclical
# GOOGL  GOOGL                    Alphabet Inc.  Communication Services
# IPG      IPG  Interpublic Group of Companies,  Communication Services
#
#                                   Industry        Country  MarketCap(BN)  \
# AMBA   Semiconductor Equipment & Materials  United States           2.02
# PATH             Software - Infrastructure  United States          12.34
# PFE           Drug Manufacturers - General  United States         151.64
# SONY                  Consumer Electronics          Japan         104.54
# TM                      Auto Manufacturers          Japan         335.05
# AEP         Utilities - Regulated Electric  United States          44.80
# EPD                    Oil & Gas Midstream  United States          63.44
# TSLA                    Auto Manufacturers  United States         563.33
# GOOGL       Internet Content & Information  United States        1953.13
# IPG                   Advertising Agencies  United States          12.02
#
#         P/B  Dividend Yield(%)  Payout Ratio (%)  EPS(ttm)  \
# AMBA   3.62               0.00              0.00     -4.25
# PATH   6.14               0.00              0.00     -0.16
# PFE    1.70               6.27            443.24      0.37
# SONY   0.01               0.63             11.38      4.57
# TM     0.10               1.62             19.00     21.93
# AEP    1.77               4.14             79.48      4.24
# EPD    2.29               7.04             78.57      2.52
# TSLA   8.99               0.00              0.00      4.30
# GOOGL  6.89               0.00              0.00      5.79
# IPG    3.05               4.16             43.51      2.85
#
#        EPS growth past 5 years(%)  ROE(%)  Current Ratio  LT Debt/Equity  \
# AMBA                       -35.48  -29.06           3.38            0.00
# PATH                        20.57   -4.57           3.63            0.03
# PFE                        -27.43    2.35           0.91            0.72
# SONY                         9.82   12.12           0.69            0.25
# TM                          -2.71   14.72           1.18            0.59
# AEP                          1.73    8.96           0.53            1.52
# EPD                          5.54   20.00           0.93            1.01
# TSLA                         0.00   27.35           1.73            0.10
# GOOGL                       21.56   27.36           2.10            0.09
# IPG                         12.34   28.83           1.06            1.05
#
#        Total Debt/Equity   Price     P/E  E/P (%)  PriceToAssets
# AMBA                0.01   50.22  -11.82    -8.46            NaN
# PATH                0.03   21.80 -136.25    -0.73            NaN
# PFE                 0.84   26.78   72.38     1.38           3.76
# SONY                0.59   84.64   18.52     5.40           1.01
# TM                  1.01  246.93   11.26     8.88           7.02
# AEP                 1.74   85.08   20.07     4.98          12.99
# EPD                 1.01   29.26   11.61     8.61          11.39
# TSLA                0.15  176.88   41.13     2.43          29.49
# GOOGL               0.11  156.60   27.05     3.70          29.96
# IPG                 1.15   31.75   11.14     8.98          13.99

# %% [markdown]
# Armado de Dataframe con Financials de los tickers

# %%
indexList = ['Total Revenue', 'Pretax Income']

finanDF = pd.DataFrame(columns=indexList)


for ticker in tickers:

  tickerFinancialDf = yf.Ticker(ticker).financials

  df2 = tickerFinancialDf[tickerFinancialDf.index.isin(indexList)] \
    .transpose() \
    .sort_index(ascending=False) \
    .head(1)

  df2 = df2 / 1000000
  df2['Ticker'] = ticker
  df2 = df2.set_index('Ticker')

  finanDF = pd.concat([finanDF, df2])


#df = df.astype({'Total Revenue': float, 'Pretax Income':float})
#finanDF.info()
#print(finanDF)

finalDF =  df.join(finanDF) \
  .rename(columns={'Total Revenue': 'Total Revenue(M) ', 'Pretax Income': 'Pretax Income(M)'})

#finalDF = finalDF.astype({'EPS growth past 5 years(%)': float, 'LT Debt/Equity':float, 'Total Revenue(M)':float, 'Pretax Income(M)':float})

print(finalDF)
# Out:
#       Ticker                          Company                  Sector  \
# AMBA    AMBA                  Ambarella, Inc.              Technology
# PATH    PATH                     UiPath, Inc.              Technology
# PFE      PFE                     Pfizer, Inc.              Healthcare
# SONY    SONY           Sony Group Corporation              Technology
# TM        TM         Toyota Motor Corporation       Consumer Cyclical
# AEP      AEP  American Electric Power Company               Utilities
# EPD      EPD  Enterprise Products Partners L.                  Energy
# TSLA    TSLA                      Tesla, Inc.       Consumer Cyclical
# GOOGL  GOOGL                    Alphabet Inc.  Communication Services
# IPG      IPG  Interpublic Group of Companies,  Communication Services
#
#                                   Industry        Country  MarketCap(BN)  \
# AMBA   Semiconductor Equipment & Materials  United States           2.02
# PATH             Software - Infrastructure  United States          12.34
# PFE           Drug Manufacturers - General  United States         151.64
# SONY                  Consumer Electronics          Japan         104.54
# TM                      Auto Manufacturers          Japan         335.05
# AEP         Utilities - Regulated Electric  United States          44.80
# EPD                    Oil & Gas Midstream  United States          63.44
# TSLA                    Auto Manufacturers  United States         563.33
# GOOGL       Internet Content & Information  United States        1953.13
# IPG                   Advertising Agencies  United States          12.02
#
#         P/B  Dividend Yield(%)  Payout Ratio (%)  EPS(ttm)  ...  ROE(%)  \
# AMBA   3.62               0.00              0.00     -4.25  ...  -29.06
# PATH   6.14               0.00              0.00     -0.16  ...   -4.57
# PFE    1.70               6.27            443.24      0.37  ...    2.35
# SONY   0.01               0.63             11.38      4.57  ...   12.12
# TM     0.10               1.62             19.00     21.93  ...   14.72
# AEP    1.77               4.14             79.48      4.24  ...    8.96
# EPD    2.29               7.04             78.57      2.52  ...   20.00
# TSLA   8.99               0.00              0.00      4.30  ...   27.35
# GOOGL  6.89               0.00              0.00      5.79  ...   27.36
# IPG    3.05               4.16             43.51      2.85  ...   28.83
#
#        Current Ratio  LT Debt/Equity  Total Debt/Equity   Price     P/E  \
# AMBA            3.38            0.00               0.01   50.22  -11.82
# PATH            3.63            0.03               0.03   21.80 -136.25
# PFE             0.91            0.72               0.84   26.78   72.38
# SONY            0.69            0.25               0.59   84.64   18.52
# TM              1.18            0.59               1.01  246.93   11.26
# AEP             0.53            1.52               1.74   85.08   20.07
# EPD             0.93            1.01               1.01   29.26   11.61
# TSLA            1.73            0.10               0.15  176.88   41.13
# GOOGL           2.10            0.09               0.11  156.60   27.05
# IPG             1.06            1.05               1.15   31.75   11.14
#
#        E/P (%)  PriceToAssets  Total Revenue(M)  Pretax Income(M)
# AMBA     -8.46            NaN            226.474          -148.53
# PATH     -0.73            NaN           1308.072          -75.815
# PFE       1.38           3.76            58496.0           1058.0
# SONY      5.40           1.01         11539837.0        1180313.0
# TM        8.88           7.02         37154298.0        3668733.0
# AEP       4.98          12.99            18982.3           2208.7
# EPD       8.61          11.39            49715.0           5701.0
# TSLA      2.43          29.49            96773.0           9973.0
# GOOGL     3.70          29.96           307394.0          85717.0
# IPG       8.98          13.99            10889.3           1408.0
#
# [10 rows x 21 columns]

# %% [markdown]
# Armado de Dataframe con Balance Sheet de los tickers

# %%
indexList = ['Total Assets', 'Current Assets', 'Current Liabilities','Long Term Debt']

balanceSheetDF = pd.DataFrame(columns=indexList)

for ticker in tickers:

  tickerBalanceSheetDf = yf.Ticker(ticker).balancesheet

  df2 = tickerBalanceSheetDf[tickerBalanceSheetDf.index.isin(indexList)] \
    .transpose() \
    .sort_index(ascending=False) \
    .head(1)

  df2 = df2 / 1000000
  df2['Ticker'] = ticker
  df2 = df2.set_index('Ticker')
  balanceSheetDF = pd.concat([balanceSheetDF, df2])

finalDF =  finalDF.join(balanceSheetDF) \
  .rename(columns={'Total Assets': 'Total Assets(M) ', 'Current Assets': 'Current Assets(M)', 'Current Liabilities':'Current Liabilities(M)', 'Long Term Debt':'Long Term Debt(M)'})

finalDF['Net Current Assets(M)'] = finalDF['Current Assets(M)']- finalDF['Current Liabilities(M)']
#df = df.astype({'EPS growth past 5 years(%)': float, 'LT Debt/Equity':float, 'Total Revenue':float, 'Pretax Income':float})

print(finalDF)
# Out:
#       Ticker                          Company                  Sector  \
# AMBA    AMBA                  Ambarella, Inc.              Technology
# PATH    PATH                     UiPath, Inc.              Technology
# PFE      PFE                     Pfizer, Inc.              Healthcare
# SONY    SONY           Sony Group Corporation              Technology
# TM        TM         Toyota Motor Corporation       Consumer Cyclical
# AEP      AEP  American Electric Power Company               Utilities
# EPD      EPD  Enterprise Products Partners L.                  Energy
# TSLA    TSLA                      Tesla, Inc.       Consumer Cyclical
# GOOGL  GOOGL                    Alphabet Inc.  Communication Services
# IPG      IPG  Interpublic Group of Companies,  Communication Services
#
#                                   Industry        Country  MarketCap(BN)  \
# AMBA   Semiconductor Equipment & Materials  United States           2.02
# PATH             Software - Infrastructure  United States          12.34
# PFE           Drug Manufacturers - General  United States         151.64
# SONY                  Consumer Electronics          Japan         104.54
# TM                      Auto Manufacturers          Japan         335.05
# AEP         Utilities - Regulated Electric  United States          44.80
# EPD                    Oil & Gas Midstream  United States          63.44
# TSLA                    Auto Manufacturers  United States         563.33
# GOOGL       Internet Content & Information  United States        1953.13
# IPG                   Advertising Agencies  United States          12.02
#
#         P/B  Dividend Yield(%)  Payout Ratio (%)  EPS(ttm)  ...     P/E  \
# AMBA   3.62               0.00              0.00     -4.25  ...  -11.82
# PATH   6.14               0.00              0.00     -0.16  ... -136.25
# PFE    1.70               6.27            443.24      0.37  ...   72.38
# SONY   0.01               0.63             11.38      4.57  ...   18.52
# TM     0.10               1.62             19.00     21.93  ...   11.26
# AEP    1.77               4.14             79.48      4.24  ...   20.07
# EPD    2.29               7.04             78.57      2.52  ...   11.61
# TSLA   8.99               0.00              0.00      4.30  ...   41.13
# GOOGL  6.89               0.00              0.00      5.79  ...   27.05
# IPG    3.05               4.16             43.51      2.85  ...   11.14
#
#        E/P (%)  PriceToAssets  Total Revenue(M)   Pretax Income(M)  \
# AMBA     -8.46            NaN            226.474           -148.53
# PATH     -0.73            NaN           1308.072           -75.815
# PFE       1.38           3.76            58496.0            1058.0
# SONY      5.40           1.01         11539837.0         1180313.0
# TM        8.88           7.02         37154298.0         3668733.0
# AEP       4.98          12.99            18982.3            2208.7
# EPD       8.61          11.39            49715.0            5701.0
# TSLA      2.43          29.49            96773.0            9973.0
# GOOGL     3.70          29.96           307394.0           85717.0
# IPG       8.98          13.99            10889.3            1408.0
#
#        Total Assets(M)   Current Assets(M)  Current Liabilities(M)  \
# AMBA            657.655            280.157                  82.979
# PATH           2954.758           2580.412                 711.691
# PFE            226501.0            43333.0                 47794.0
# SONY         32041222.0          5776518.0               9308936.0
# TM           74303180.0         26459781.0              23959715.0
# AEP             96684.0             6082.1                 11583.6
# EPD             70982.0            12248.0                 13131.0
# TSLA           106618.0            49616.0                 28748.0
# GOOGL          402392.0           171530.0                 81814.0
# IPG             19267.3            10950.4                 10330.9
#
#        Long Term Debt(M) Net Current Assets(M)
# AMBA                 NaN               197.178
# PATH                 NaN              1868.721
# PFE              60499.0               -4461.0
# SONY           1767696.0            -3532418.0
# TM            16685384.0             2500066.0
# AEP              37652.7               -5501.5
# EPD              27448.0                -883.0
# TSLA              2682.0               20868.0
# GOOGL            11870.0               89716.0
# IPG               2917.5                 619.5
#
# [10 rows x 26 columns]

# %% [markdown]
# Armado de Dataframe con año minimo de pago de dividendos

# %%
tickersDividendData = []

for ticker in tickers:
  tickerActionsDf = yf.Ticker(ticker).actions

  if len(tickerActionsDf.index) > 0:
    tickerActionsDf['Date'] = tickerActionsDf.index

    firstDividendRecordYear = tickerActionsDf.iloc[tickerActionsDf['Date'].argmin()]['Date'].year

    zeroDividendsDF = tickerActionsDf.query("Dividends == 0")

    contDividendsPaymentSince = firstDividendRecordYear if zeroDividendsDF.empty else zeroDividendsDF.iloc[zeroDividendsDF['Date'].argmax()]['Date'].year+1

    tickerDividendData = [
        firstDividendRecordYear,
        contDividendsPaymentSince
    ]
  else:
    tickerDividendData = [
        np.nan,
        np.nan
    ]

  tickersDividendData.append(tickerDividendData)

columnsNames = ['First Dividend Record','Continue Dividends Payment Since']

dividendDF = pd.DataFrame(tickersDividendData, index = tickers, columns=columnsNames )

finalDF = finalDF.join(dividendDF)
print(finalDF)
# Out:
#       Ticker                          Company                  Sector  \
# AMBA    AMBA                  Ambarella, Inc.              Technology
# PATH    PATH                     UiPath, Inc.              Technology
# PFE      PFE                     Pfizer, Inc.              Healthcare
# SONY    SONY           Sony Group Corporation              Technology
# TM        TM         Toyota Motor Corporation       Consumer Cyclical
# AEP      AEP  American Electric Power Company               Utilities
# EPD      EPD  Enterprise Products Partners L.                  Energy
# TSLA    TSLA                      Tesla, Inc.       Consumer Cyclical
# GOOGL  GOOGL                    Alphabet Inc.  Communication Services
# IPG      IPG  Interpublic Group of Companies,  Communication Services
#
#                                   Industry        Country  MarketCap(BN)  \
# AMBA   Semiconductor Equipment & Materials  United States           2.02
# PATH             Software - Infrastructure  United States          12.34
# PFE           Drug Manufacturers - General  United States         151.64
# SONY                  Consumer Electronics          Japan         104.54
# TM                      Auto Manufacturers          Japan         335.05
# AEP         Utilities - Regulated Electric  United States          44.80
# EPD                    Oil & Gas Midstream  United States          63.44
# TSLA                    Auto Manufacturers  United States         563.33
# GOOGL       Internet Content & Information  United States        1953.13
# IPG                   Advertising Agencies  United States          12.02
#
#         P/B  Dividend Yield(%)  Payout Ratio (%)  EPS(ttm)  ...  \
# AMBA   3.62               0.00              0.00     -4.25  ...
# PATH   6.14               0.00              0.00     -0.16  ...
# PFE    1.70               6.27            443.24      0.37  ...
# SONY   0.01               0.63             11.38      4.57  ...
# TM     0.10               1.62             19.00     21.93  ...
# AEP    1.77               4.14             79.48      4.24  ...
# EPD    2.29               7.04             78.57      2.52  ...
# TSLA   8.99               0.00              0.00      4.30  ...
# GOOGL  6.89               0.00              0.00      5.79  ...
# IPG    3.05               4.16             43.51      2.85  ...
#
#        PriceToAssets  Total Revenue(M)   Pretax Income(M)  Total Assets(M)   \
# AMBA             NaN            226.474           -148.53           657.655
# PATH             NaN           1308.072           -75.815          2954.758
# PFE             3.76            58496.0            1058.0          226501.0
# SONY            1.01         11539837.0         1180313.0        32041222.0
# TM              7.02         37154298.0         3668733.0        74303180.0
# AEP            12.99            18982.3            2208.7           96684.0
# EPD            11.39            49715.0            5701.0           70982.0
# TSLA           29.49            96773.0            9973.0          106618.0
# GOOGL          29.96           307394.0           85717.0          402392.0
# IPG            13.99            10889.3            1408.0           19267.3
#
#        Current Assets(M)  Current Liabilities(M)  Long Term Debt(M)  \
# AMBA             280.157                  82.979                NaN
# PATH            2580.412                 711.691                NaN
# PFE              43333.0                 47794.0            60499.0
# SONY           5776518.0               9308936.0          1767696.0
# TM            26459781.0              23959715.0         16685384.0
# AEP               6082.1                 11583.6            37652.7
# EPD              12248.0                 13131.0            27448.0
# TSLA             49616.0                 28748.0             2682.0
# GOOGL           171530.0                 81814.0            11870.0
# IPG              10950.4                 10330.9             2917.5
#
#        Net Current Assets(M)  First Dividend Record  \
# AMBA                 197.178                    NaN
# PATH                1868.721                    NaN
# PFE                  -4461.0                 1972.0
# SONY              -3532418.0                 1973.0
# TM                 2500066.0                 1980.0
# AEP                  -5501.5                 1962.0
# EPD                   -883.0                 1998.0
# TSLA                 20868.0                 2020.0
# GOOGL                89716.0                 2014.0
# IPG                    619.5                 1984.0
#
#       Continue Dividends Payment Since
# AMBA                               NaN
# PATH                               NaN
# PFE                             2021.0
# SONY                            2001.0
# TM                              1992.0
# AEP                             1963.0
# EPD                             2015.0
# TSLA                            2023.0
# GOOGL                           2023.0
# IPG                             2000.0
#
# [10 rows x 28 columns]

# %% [markdown]
# Integracion a API AlphaVantage para info de Earnings

# %%
import requests
import json
#from google.colab import userdata
#from google.colab import drive

#drive.mount('/content/drive')

earningsConcatDF = pd.DataFrame()
#aplhaVantageApiKey = userdata.get('alphaVantageApiKey')

for ticker in tickers:
  # replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key

  url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol='+ticker+'&apikey=AN3GO9IIJDP6KJ09'
  #url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol=IBMB&apikey=demo'
  r = requests.get(url)
  #print(r.json())
  data = r.json()['annualEarnings']

  #with open('/content/drive/MyDrive/Colab Notebooks/query.json') as f:
    #jsonData = json.load(f)
  #data = jsonData['annualEarnings']

  earningsDF=pd.DataFrame(data)
  earningsDF['Year']=earningsDF['fiscalDateEnding'].str[:4]
  earningsDF['Ticker'] = ticker
  #earningsDF['Ticker'] = 'IBM'
  earningsDF = earningsDF.drop('fiscalDateEnding', axis=1) \
    .loc[earningsDF['Year'] <= year] \
    .sort_values(by=['Year'], ascending=False) \
    .head(10) \
    .set_index('Ticker') \
    .pivot(columns='Year', values='reportedEPS') \
    .apply(pd.to_numeric)

  #print(earningsDF)

  #Cambio los nombres a las columnas de earnings anuales por uno genérico para no tener el año como referencia
  for num in range(0,10):
    yearEPS = int(year) - num
    earningsDF.rename(columns={str(yearEPS):'EPS LastYear'+ ('' if num == 0 else '-'+str(num))}, inplace=True)

  earningsDF = earningsDF.sort_index(axis=1)

  earningsConcatDF = pd.concat([earningsConcatDF, earningsDF])

finalDF = finalDF.join(earningsConcatDF)

print(finalDF)
# Out:
#       Ticker                          Company                  Sector  \
# AMBA    AMBA                  Ambarella, Inc.              Technology
# PATH    PATH                     UiPath, Inc.              Technology
# PFE      PFE                     Pfizer, Inc.              Healthcare
# SONY    SONY           Sony Group Corporation              Technology
# TM        TM         Toyota Motor Corporation       Consumer Cyclical
# AEP      AEP  American Electric Power Company               Utilities
# EPD      EPD  Enterprise Products Partners L.                  Energy
# TSLA    TSLA                      Tesla, Inc.       Consumer Cyclical
# GOOGL  GOOGL                    Alphabet Inc.  Communication Services
# IPG      IPG  Interpublic Group of Companies,  Communication Services
#
#                                   Industry        Country  MarketCap(BN)  \
# AMBA   Semiconductor Equipment & Materials  United States           2.02
# PATH             Software - Infrastructure  United States          12.34
# PFE           Drug Manufacturers - General  United States         151.64
# SONY                  Consumer Electronics          Japan         104.54
# TM                      Auto Manufacturers          Japan         335.05
# AEP         Utilities - Regulated Electric  United States          44.80
# EPD                    Oil & Gas Midstream  United States          63.44
# TSLA                    Auto Manufacturers  United States         563.33
# GOOGL       Internet Content & Information  United States        1953.13
# IPG                   Advertising Agencies  United States          12.02
#
#         P/B  Dividend Yield(%)  Payout Ratio (%)  EPS(ttm)  ...  EPS LastYear  \
# AMBA   3.62               0.00              0.00     -4.25  ...          1.11
# PATH   6.14               0.00              0.00     -0.16  ...          0.15
# PFE    1.70               6.27            443.24      0.37  ...          1.83
# SONY   0.01               0.63             11.38      4.57  ...          5.55
# TM     0.10               1.62             19.00     21.93  ...         13.27
# AEP    1.77               4.14             79.48      4.24  ...          5.24
# EPD    2.29               7.04             78.57      2.52  ...          2.52
# TSLA   8.99               0.00              0.00      4.30  ...          3.13
# GOOGL  6.89               0.00              0.00      5.79  ...          5.80
# IPG    3.05               4.16             43.51      2.85  ...          2.83
#
#        EPS LastYear-1  EPS LastYear-2  EPS LastYear-3  EPS LastYear-4  \
# AMBA            1.600            0.33          0.6800           0.730
# PATH           -0.154            0.09             NaN             NaN
# PFE             6.630            4.42          2.7200           2.950
# SONY            6.350            8.77          4.2400           6.460
# TM             17.750           15.15         13.5431          11.660
# AEP             5.090            4.74          4.4400           4.250
# EPD             2.500            2.10          1.7100           2.080
# TSLA            4.070            2.26          0.7500           0.070
# GOOGL           4.550            5.60          2.9435           2.459
# IPG             2.750            2.60          1.7300           1.940
#
#        EPS LastYear-5  EPS LastYear-6  EPS LastYear-7  EPS LastYear-8  \
# AMBA            2.070          2.9100          3.3100          1.9800
# PATH              NaN             NaN             NaN             NaN
# PFE             3.000          2.6500          2.3900          2.2000
# SONY            3.430          0.5200         93.5136         -1.0654
# TM            364.530          8.0035          1.2439          1.1989
# AEP             3.950          3.6600          3.9400          3.7000
# EPD             2.060          1.3200          1.2000          1.3600
# TSLA           -0.060         -0.5700         -0.1100         -1.3000
# GOOGL           2.185          1.6005          1.7170          1.4790
# IPG             1.830          1.4200          1.4032          1.4200
#
#       EPS LastYear-9
# AMBA          1.1000
# PATH             NaN
# PFE           2.2600
# SONY          0.1589
# TM            6.6778
# AEP           3.4400
# EPD           1.4500
# TSLA          0.0300
# GOOGL         1.2790
# IPG           0.9800
#
# [10 rows x 38 columns]

# %% [markdown]
# Pandas to PySpark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, round, lit, when, isnan
from pyspark.sql.types import IntegerType

#Create PySpark SparkSession
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("juaniInvestor") \
    .getOrCreate()
#Create PySpark DataFrame from Pandas
sparkDF=spark.createDataFrame(finalDF) \
  .withColumn('Net Current Assets(M)', round(col("Net Current Assets(M)"), 2))

recentlyYearsEPSColumns = [col('EPS LastYear'), \
                   col('EPS LastYear-1'), \
                   col('EPS LastYear-2')#, \
                   #col('EPS LastYear-3'), \
                   #col('EPS LastYear-4') \
                   ];

olderYearsEPSColumns = [#col('EPS LastYear-5'), \
                   #col('EPS LastYear-6'), \
                   col('EPS LastYear-7'), \
                   col('EPS LastYear-8'), \
                   col('EPS LastYear-9') \
                   ]

midYearsEPSColumns = [col('EPS LastYear-3'), \
                        col('EPS LastYear-4'), \
                        col('EPS LastYear-5'), \
                        col('EPS LastYear-6')]

sparkDF = sparkDF.withColumn('Recently Years EPS Avg', round(sum(x for x in recentlyYearsEPSColumns) \
              /len(recentlyYearsEPSColumns),2)) \
            .withColumn('Older Years EPS Avg', round(sum(x for x in olderYearsEPSColumns) \
              /len(olderYearsEPSColumns),2)) \
            .withColumn('Growth', round(col('Recently Years EPS Avg')-col('Older Years EPS Avg'),2)) \
            .withColumn('Growth(%)', round(col('Growth')*100/col('Older Years EPS Avg'),2)) \
            .withColumn('Value', round(col('EPS LastYear')*(8.5+2*((col('Growth(%)')-31.14)*0.1)),2)) \
            .withColumn('Margin of Safety', round(col('Value')/col('Price'),2)) \
            .withColumn('Max Entry Price', round(when(col('EPS(ttm)')*15 < col('Value'), col('EPS(ttm)')*15) \
                                                  .otherwise(col('Value')),2)) \
            .withColumn('Test2-1', col('Current Ratio') >= 2) \
            .withColumn('Test2-2', col('Long Term Debt(M)') < col('Net Current Assets(M)')) \
            .withColumn('Test3', sum(when((col < 0)|(isnan(col)), lit(1)).otherwise(lit(0)) for col in recentlyYearsEPSColumns + olderYearsEPSColumns + midYearsEPSColumns) == 0) \
            .withColumn('Test4', (year-col('Continue Dividends Payment Since')).cast(IntegerType()) >= 20) \
            .withColumn('Test5', col('Growth(%)') >= 66.3) \
            .withColumn('Test6', col('P/E') < 15) \
            .withColumn('Test7', col('PriceToAssets') < 22.5) \
            .withColumn('Test8', col('Margin of Safety') > 1)

sparkDF.printSchema()
sparkDF.show()


sparkDF.write.option("header",True) \
  .mode('overwrite') \
  .parquet("data\portfilio_stocks.parquet")
# Out:
# 24/04/10 09:51:03 WARN Utils: Your hostname, juani-notebook resolves to a loopback address: 127.0.1.1; using 192.168.1.104 instead (on interface wlp2s0)
# 24/04/10 09:51:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/10 09:51:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# root
#  |-- Ticker: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- Sector: string (nullable = true)
#  |-- Industry: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- MarketCap(BN): double (nullable = true)
#  |-- P/B: double (nullable = true)
#  |-- Dividend Yield(%): double (nullable = true)
#  |-- Payout Ratio (%): double (nullable = true)
#  |-- EPS(ttm): double (nullable = true)
#  |-- EPS growth past 5 years(%): double (nullable = true)
#  |-- ROE(%): double (nullable = true)
#  |-- Current Ratio: double (nullable = true)
#  |-- LT Debt/Equity: double (nullable = true)
#  |-- Total Debt/Equity: double (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- P/E: double (nullable = true)
#  |-- E/P (%): double (nullable = true)
#  |-- PriceToAssets: double (nullable = true)
#  |-- Total Revenue(M) : double (nullable = true)
#  |-- Pretax Income(M): double (nullable = true)
#  |-- Total Assets(M) : double (nullable = true)
#  |-- Current Assets(M): double (nullable = true)
#  |-- Current Liabilities(M): double (nullable = true)
#  |-- Long Term Debt(M): double (nullable = true)
#  |-- Net Current Assets(M): double (nullable = true)
#  |-- First Dividend Record: double (nullable = true)
#  |-- Continue Dividends Payment Since: double (nullable = true)
#  |-- EPS LastYear: double (nullable = true)
#  |-- EPS LastYear-1: double (nullable = true)
#  |-- EPS LastYear-2: double (nullable = true)
#  |-- EPS LastYear-3: double (nullable = true)
#  |-- EPS LastYear-4: double (nullable = true)
#  |-- EPS LastYear-5: double (nullable = true)
#  |-- EPS LastYear-6: double (nullable = true)
#  |-- EPS LastYear-7: double (nullable = true)
#  |-- EPS LastYear-8: double (nullable = true)
#  |-- EPS LastYear-9: double (nullable = true)
#  |-- Recently Years EPS Avg: double (nullable = true)
#  |-- Older Years EPS Avg: double (nullable = true)
#  |-- Growth: double (nullable = true)
#  |-- Growth(%): double (nullable = true)
#  |-- Value: double (nullable = true)
#  |-- Margin of Safety: double (nullable = true)
#  |-- Max Entry Price: double (nullable = true)
#  |-- Test2-1: boolean (nullable = true)
#  |-- Test2-2: boolean (nullable = true)
#  |-- Test3: boolean (nullable = false)
#  |-- Test4: boolean (nullable = true)
#  |-- Test5: boolean (nullable = true)
#  |-- Test6: boolean (nullable = true)
#  |-- Test7: boolean (nullable = true)
#  |-- Test8: boolean (nullable = true)
# 24/04/10 09:51:11 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +------+--------------------+--------------------+--------------------+-------------+-------------+----+-----------------+----------------+--------+--------------------------+------+-------------+--------------+-----------------+------+-------+-------+-------------+-----------------+----------------+----------------+-----------------+----------------------+-----------------+---------------------+---------------------+--------------------------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------------------+-------------------+------+---------+-------+----------------+---------------+-------+-------+-----+-----+-----+-----+-----+-----+
# |Ticker|             Company|              Sector|            Industry|      Country|MarketCap(BN)| P/B|Dividend Yield(%)|Payout Ratio (%)|EPS(ttm)|EPS growth past 5 years(%)|ROE(%)|Current Ratio|LT Debt/Equity|Total Debt/Equity| Price|    P/E|E/P (%)|PriceToAssets|Total Revenue(M) |Pretax Income(M)|Total Assets(M) |Current Assets(M)|Current Liabilities(M)|Long Term Debt(M)|Net Current Assets(M)|First Dividend Record|Continue Dividends Payment Since|EPS LastYear|EPS LastYear-1|EPS LastYear-2|EPS LastYear-3|EPS LastYear-4|EPS LastYear-5|EPS LastYear-6|EPS LastYear-7|EPS LastYear-8|EPS LastYear-9|Recently Years EPS Avg|Older Years EPS Avg|Growth|Growth(%)|  Value|Margin of Safety|Max Entry Price|Test2-1|Test2-2|Test3|Test4|Test5|Test6|Test7|Test8|
# +------+--------------------+--------------------+--------------------+-------------+-------------+----+-----------------+----------------+--------+--------------------------+------+-------------+--------------+-----------------+------+-------+-------+-------------+-----------------+----------------+----------------+-----------------+----------------------+-----------------+---------------------+---------------------+--------------------------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------------------+-------------------+------+---------+-------+----------------+---------------+-------+-------+-----+-----+-----+-----+-----+-----+
# |  AMBA|     Ambarella, Inc.|          Technology|Semiconductor Equ...|United States|         2.02|3.62|              0.0|             0.0|   -4.25|                    -35.48|-29.06|         3.38|           0.0|             0.01| 50.22| -11.82|  -8.46|          NaN|          226.474|         -148.53|         657.655|          280.157|                82.979|              NaN|               197.18|                  NaN|                             NaN|        1.11|           1.6|          0.33|          0.68|          0.73|          2.07|          2.91|          3.31|          1.98|           1.1|                  1.01|               2.13| -1.12|   -52.58|  -9.15|           -0.18|         -63.75|   true|  false| true|false|false| true|false|false|
# |  PATH|        UiPath, Inc.|          Technology|Software - Infras...|United States|        12.34|6.14|              0.0|             0.0|   -0.16|                     20.57| -4.57|         3.63|          0.03|             0.03|  21.8|-136.25|  -0.73|          NaN|         1308.072|         -75.815|        2954.758|         2580.412|               711.691|              NaN|              1868.72|                  NaN|                             NaN|        0.15|        -0.154|          0.09|           NaN|           NaN|           NaN|           NaN|           NaN|           NaN|           NaN|                  0.03|                NaN|   NaN|      NaN|    NaN|             NaN|           -2.4|   true|  false|false|false| true| true|false| true|
# |   PFE|        Pfizer, Inc.|          Healthcare|Drug Manufacturer...|United States|       151.64| 1.7|             6.27|          443.24|    0.37|                    -27.43|  2.35|         0.91|          0.72|             0.84| 26.78|  72.38|   1.38|         3.76|          58496.0|          1058.0|        226501.0|          43333.0|               47794.0|          60499.0|              -4461.0|               1972.0|                          2021.0|        1.83|          6.63|          4.42|          2.72|          2.95|           3.0|          2.65|          2.39|           2.2|          2.26|                  4.29|               2.28|  2.01|    88.16|  36.42|            1.36|           5.55|  false|  false| true|false| true|false| true| true|
# |  SONY|Sony Group Corpor...|          Technology|Consumer Electronics|        Japan|       104.54|0.01|             0.63|           11.38|    4.57|                      9.82| 12.12|         0.69|          0.25|             0.59| 84.64|  18.52|    5.4|         1.01|      1.1539837E7|       1180313.0|     3.2041222E7|        5776518.0|             9308936.0|        1767696.0|           -3532418.0|               1973.0|                          2001.0|        5.55|          6.35|          8.77|          4.24|          6.46|          3.43|          0.52|       93.5136|       -1.0654|        0.1589|                  6.89|              30.87|-23.98|   -77.68| -73.62|           -0.87|         -73.62|  false|  false|false| true|false|false| true|false|
# |    TM|Toyota Motor Corp...|   Consumer Cyclical|  Auto Manufacturers|        Japan|       335.05| 0.1|             1.62|            19.0|   21.93|                     -2.71| 14.72|         1.18|          0.59|             1.01|246.93|  11.26|   8.88|         7.02|      3.7154298E7|       3668733.0|      7.430318E7|      2.6459781E7|           2.3959715E7|      1.6685384E7|            2500066.0|               1980.0|                          1992.0|       13.27|         17.75|         15.15|       13.5431|         11.66|        364.53|        8.0035|        1.2439|        1.1989|        6.6778|                 15.39|               3.04| 12.35|   406.25|1108.34|            4.49|         328.95|  false|  false| true| true| true| true| true| true|
# |   AEP|American Electric...|           Utilities|Utilities - Regul...|United States|         44.8|1.77|             4.14|           79.48|    4.24|                      1.73|  8.96|         0.53|          1.52|             1.74| 85.08|  20.07|   4.98|        12.99|          18982.3|          2208.7|         96684.0|           6082.1|               11583.6|          37652.7|              -5501.5|               1962.0|                          1963.0|        5.24|          5.09|          4.74|          4.44|          4.25|          3.95|          3.66|          3.94|           3.7|          3.44|                  5.02|               3.69|  1.33|    36.04|  49.68|            0.58|          49.68|  false|  false| true| true|false|false| true|false|
# |   EPD|Enterprise Produc...|              Energy| Oil & Gas Midstream|United States|        63.44|2.29|             7.04|           78.57|    2.52|                      5.54|  20.0|         0.93|          1.01|             1.01| 29.26|  11.61|   8.61|        11.39|          49715.0|          5701.0|         70982.0|          12248.0|               13131.0|          27448.0|               -883.0|               1998.0|                          2015.0|        2.52|           2.5|           2.1|          1.71|          2.08|          2.06|          1.32|           1.2|          1.36|          1.45|                  2.37|               1.34|  1.03|    76.87|  44.47|            1.52|           37.8|  false|  false| true|false| true| true| true| true|
# |  TSLA|         Tesla, Inc.|   Consumer Cyclical|  Auto Manufacturers|United States|       563.33|8.99|              0.0|             0.0|     4.3|                       0.0| 27.35|         1.73|           0.1|             0.15|176.88|  41.13|   2.43|        29.49|          96773.0|          9973.0|        106618.0|          49616.0|               28748.0|           2682.0|              20868.0|               2020.0|                          2023.0|        3.13|          4.07|          2.26|          0.75|          0.07|         -0.06|         -0.57|         -0.11|          -1.3|          0.03|                  3.15|              -0.46|  3.61|  -784.78|-484.16|           -2.74|        -484.16|  false|   true|false|false|false|false|false|false|
# | GOOGL|       Alphabet Inc.|Communication Ser...|Internet Content ...|United States|      1953.13|6.89|              0.0|             0.0|    5.79|                     21.56| 27.36|          2.1|          0.09|             0.11| 156.6|  27.05|    3.7|        29.96|         307394.0|         85717.0|        402392.0|         171530.0|               81814.0|          11870.0|              89716.0|               2014.0|                          2023.0|         5.8|          4.55|           5.6|        2.9435|         2.459|         2.185|        1.6005|         1.717|         1.479|         1.279|                  5.32|               1.49|  3.83|   257.05| 311.36|            1.99|          86.85|   true|   true| true|false| true|false|false| true|
# |   IPG|Interpublic Group...|Communication Ser...|Advertising Agencies|United States|        12.02|3.05|             4.16|           43.51|    2.85|                     12.34| 28.83|         1.06|          1.05|             1.15| 31.75|  11.14|   8.98|        13.99|          10889.3|          1408.0|         19267.3|          10950.4|               10330.9|           2917.5|                619.5|               1984.0|                          2000.0|        2.83|          2.75|           2.6|          1.73|          1.94|          1.83|          1.42|        1.4032|          1.42|          0.98|                  2.73|               1.27|  1.46|   114.96|   71.5|            2.25|          42.75|  false|  false| true| true| true| true| true| true|
# +------+--------------------+--------------------+--------------------+-------------+-------------+----+-----------------+----------------+--------+--------------------------+------+-------------+--------------+-----------------+------+-------+-------+-------------+-----------------+----------------+----------------+-----------------+----------------------+-----------------+---------------------+---------------------+--------------------------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------------------+-------------------+------+---------+-------+----------------+---------------+-------+-------+-----+-----+-----+-----+-----+-----+

# %%
# !pip install sqlalchemy psycopg2-binary 

from sqlalchemy import create_engine

import pyarrow.parquet as pq

engine = create_engine(f'postgresql://root:root@localhost:5432/billionsDB')

pandasDF = sparkDF.toPandas()

print(pandasDF.to_sql(name='grahamStockMetrics', con=engine, index=False,if_exists='append'))

conn.close()
# Out:
# Requirement already satisfied: sqlalchemy in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (2.0.25)
# Requirement already satisfied: psycopg2-binary in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (2.9.9)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/juani/data-engineering-zoomcamp/lib/python3.10/site-packages (from sqlalchemy) (3.0.3)
# 10
