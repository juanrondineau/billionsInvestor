# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit, when, isnan,round as pysparkround
from pyspark.sql.types import IntegerType

#Create PySpark SparkSession
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("juaniInvestor") \
    .getOrCreate()

parDF=spark.read.parquet("./data/parquets/graham.parquet/*.*")

parDF.show()
# Out:
# +------+--------------------+------------------+--------------------+-------------+-------------+----+-----------------+----------------+--------+--------------------------+------+-------------+--------------+-----------------+-----+--------------------+-----+-------+-------------+----------------+----------------+---------------+-----------------+----------------------+-----------------+---------------------+---------------------+--------------------------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------------------+-------------------+------+---------+-------+----------------+---------------+-------------+-----+-----+-------+-------+-----+-----+-----+-----+-----+-----+----------+
# |Ticker|             Company|            Sector|            Industry|      Country|MarketCap(BN)| P/B|Dividend Yield(%)|Payout Ratio (%)|EPS(ttm)|EPS growth past 5 years(%)|ROE(%)|Current Ratio|LT Debt/Equity|Total Debt/Equity|Price|          LastUpdate|  P/E|E/P (%)|PriceToAssets|Total Revenue(M)|Pretax Income(M)|Total Assets(M)|Current Assets(M)|Current Liabilities(M)|Long Term Debt(M)|Net Current Assets(M)|First Dividend Record|Continue Dividends Payment Since|EPS LastYear|EPS LastYear-1|EPS LastYear-2|EPS LastYear-3|EPS LastYear-4|EPS LastYear-5|EPS LastYear-6|EPS LastYear-7|EPS LastYear-8|EPS LastYear-9|Recently Years EPS Avg|Older Years EPS Avg|Growth|Growth(%)|  Value|Margin of Safety|Max Entry Price|Preconditions|Test0|Test1|Test2-1|Test2-2|Test3|Test4|Test5|Test6|Test7|Test8|TestPoints|
# +------+--------------------+------------------+--------------------+-------------+-------------+----+-----------------+----------------+--------+--------------------------+------+-------------+--------------+-----------------+-----+--------------------+-----+-------+-------------+----------------+----------------+---------------+-----------------+----------------------+-----------------+---------------------+---------------------+--------------------------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+----------------------+-------------------+------+---------+-------+----------------+---------------+-------------+-----+-----+-------+-------+-----+-----+-----+-----+-----+-----+----------+
# |  INTC|   Intel Corporation|        Technology|      Semiconductors|United States|       149.46|1.41|              1.4|           185.0|     0.4|                    -38.29|  1.57|         1.54|          0.45|             0.45|35.11|2024-04-18 16:42:...|87.78|   1.14|         3.56|         54228.0|           762.0|       191572.0|          43269.0|               28053.0|          46978.0|              15216.0|                 1980|                            2001|        1.01|          1.85|          5.47|          5.31|          4.89|          4.59|          3.47|          2.72|          2.34|          2.33|                  2.78|               2.46|  0.32|    13.01|   4.92|            0.14|           4.92|        false| true| true|  false|  false| true| true|false|false| true|false|         5|
